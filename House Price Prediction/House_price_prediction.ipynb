# %% [markdown]
# # Import essential liberary's

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [raw]
# 1. Title: Boston Housing Data
#
# 2. Attribute Information:
#
#     1. CRIM      per capita crime rate by town
#     2. ZN        proportion of residential land zoned for lots over
#                  25,000 sq.ft.
#     3. INDUS     proportion of non-retail business acres per town
#     4. CHAS      Charles River dummy variable (= 1 if tract bounds
#                  river; 0 otherwise)
#     5. NOX       nitric oxides concentration (parts per 10 million)
#     6. RM        average number of rooms per dwelling
#     7. AGE       proportion of owner-occupied units built prior to 1940
#     8. DIS       weighted distances to five Boston employment centres
#     9. RAD       index of accessibility to radial highways
#     10. TAX      full-value property-tax rate per $10,000
#     11. PTRATIO  pupil-teacher ratio by town
#     12. B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks
#                  by town
#     13. LSTAT    % lower status of the population
#     14. MEDV     Median value of owner-occupied homes in $1000's

# %% [markdown]
# # Data Load

# %%
dat = pd.read_csv('data.csv')

# %%
dat.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
dat.shape
# Out:
# (506, 14)

# %%
dat.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         5
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null int64
# NOX        506 non-null float64
# RM         501 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null int64
# TAX        506 non-null int64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# MEDV       506 non-null float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %% [markdown]
# # Fill Missing Values

# %%
median = dat.median()
#median
data = dat.fillna(median)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null int64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null int64
# TAX        506 non-null int64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# MEDV       506 non-null float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.283587
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702126
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.618750
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
plt.figure(figsize=(16,9))
sns.heatmap(data.corr(), annot = True, cmap = 'coolwarm')
plt.title('HeatMap using correlation Matrix of Data' , fontsize =30)
# Out:
# Text(0.5, 1, 'HeatMap using correlation Matrix of Data')

# %%
data.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.218823  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311007 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391654  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091722  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.301609  0.731470
# RM      -0.218823  0.311007 -0.391654  0.091722 -0.301609  1.000000 -0.239854
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.239854  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.201815 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209753  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.291581  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.356146  0.261515
# ...

# %%
corr_matrix = data.corr()
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.695668
# ZN         0.360445
# B          0.333461
# DIS        0.249929
# CHAS       0.175260
# AGE       -0.376955
# RAD       -0.381626
# CRIM      -0.388305
# NOX       -0.427321
# TAX       -0.468536
# INDUS     -0.483725
# PTRATIO   -0.507787
# LSTAT     -0.737663
# Name: MEDV, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes = ['MEDV','RM','ZN','LSTAT']
scatter_matrix(data[attributes], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002281D6E5248>,
# ...
#       dtype=object)

# %%
data.plot(kind='scatter' , x='RM' , y='MEDV' )

# %% [markdown]
# # Train Test Split

# %%
x = data.drop(['MEDV'] , axis =1)
x.shape
# Out:
# (506, 13)

# %%
y = data['MEDV']
y.shape
# Out:
# (506,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y , test_size=0.2 , random_state=42)
print('x_train = ',x_train.shape)
print('x_test = ',x_test.shape)
print('y_train = ',y_train.shape)
print('y_test = ',y_test.shape)
# Out:
# x_train =  (404, 13)
# x_test =  (102, 13)
# y_train =  (404,)
# y_test =  (102,)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train_sc = sc.fit_transform(x_train)
x_test_sc = sc.fit_transform(x_test)

# %% [markdown]
# # Machine Learning Model Building

# %%
'''
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
x_pred = lr.predict(x_test)
lr.score(x_test,y_test)
'''
# Out:
# '\nfrom sklearn.linear_model import LinearRegression\nlr = LinearRegression()\nlr.fit(x_train,y_train)\nx_pred = lr.predict(x_test)\nlr.score(x_test,y_test)\n'

# %%
'''
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2)
poly_x_train = poly.fit_transform(x_train)
poly_x_test = poly.fit_transform(x_test)

print(poly_x_train.shape , poly_x_test.shape)

lr = LinearRegression()
lr.fit(poly_x_train,y_train)
print(lr.score(poly_x_test,y_test,))

lr.predict([poly_x_test[0,:]])
x_pred = lr.predict(poly_x_test)
#x_pred
'''
# Out:
# '\nfrom sklearn.linear_model import LinearRegression\nfrom sklearn.preprocessing import PolynomialFeatures\n\npoly = PolynomialFeatures(degree=2)\npoly_x_train = poly.fit_transform(x_train)\npoly_x_test = poly.fit_transform(x_test)\n\nprint(poly_x_train.shape , poly_x_test.shape)\n\nlr = LinearRegression()\nlr.fit(poly_x_train,y_train)\nprint(lr.score(poly_x_test,y_test,))\n\nlr.predict([poly_x_test[0,:]])\nx_pred = lr.predict(poly_x_test)\n#x_pred\n'

# %%
#datafram = pd.DataFrame(np.c_[y_test,x_pred],columns =['actual_price','predicted_price'])
#datafram.head(10)

# %%
'''
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train_sc , y_train)
x_pred = rf.predict(x_test)
rf.score(x_test_sc,y_test)
'''
# Out:
# '\nfrom sklearn.ensemble import RandomForestRegressor\nrf = RandomForestRegressor()\nrf.fit(x_train_sc , y_train)\nx_pred = rf.predict(x_test)\nrf.score(x_test_sc,y_test)\n'

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt.fit(x_train,y_train)
x_pred = dt.predict(x_test)
dt.score(x_test,y_test)
# Out:
# 0.8781210684615177

# %%
#print(lr.intercept_)
#print(lr.coef_)

# %%
'''
from sklearn.metrics import mean_squared_error,r2_score
mse = mean_squared_error(y_test,x_pred) 
rmse = r2_score(y_test,x_pred)
rmse
'''
# Out:
# '\nfrom sklearn.metrics import mean_squared_error,r2_score\nmse = mean_squared_error(y_test,x_pred) \nrmse = r2_score(y_test,x_pred)\nrmse\n'

# %%
#cross validation
from sklearn.model_selection import cross_val_score
cross_va = cross_val_score(dt,x_train,y_train,scoring="neg_mean_squared_error",cv=10)
print('cross validation = ',cross_va)
score = np.sqrt(-cross_va)
# Out:
# cross validation =  [-15.54390244 -16.86707317 -20.33536585 -53.26268293 -32.31425
#  -14.1665     -28.31675    -37.837      -21.446      -28.2795    ]

# %%
def print_score(scores):
    print('scores = ',scores)
    print('mean = ',scores.mean())
    print('std = ',scores.std())
print_score(score)
# Out:
# scores =  [3.94257561 4.10695425 4.50947512 7.29812873 5.68456243 3.76384112
#  5.32134851 6.15117875 4.63098262 5.31784731]
# mean =  5.0726894441475086
# std =  1.051058629315618

# %% [markdown]
# # Model Save

# %%
import joblib
joblib.dump(dt,'Housing.joblib')
# Out:
# ['Housing.joblib']

# %%
#testing
model = joblib.load('Housing.joblib')
features = np.array([[-0.43942006,  3.12628155, -1.12165014, -0.27288841, -1.42262747,
       -0.23979304, -1.31238772,  2.61111401, -1.0016859 , -0.5778192 ,
       -0.97491834,  0.41164221, -0.86091034]])
model.predict(features)
# Out:
# array([11.9])

# %%
#comparession between actual price and predicted price[in lacks]
dataframe = pd.DataFrame(np.c_[y_test,x_pred],columns=['actual_values','predict_values'])
dataframe.head(10)
# Out:
#    actual_values  predict_values
# 0           23.6            25.0
# 1           32.4            33.1
# 2           13.6            17.3
# 3           22.8            24.7
# 4           16.1            23.2
# 5           20.0            21.2
# 6           17.8            16.6
# 7           14.0            16.6
# 8           19.6            21.7
# 9           16.8            21.2

# %% [raw]
# Model Predictions
#
# 1:-Linear Regression
#         score = 0.666
#         mean = 4.83
#         std = 0.88
# 2:-Polynomial Regression
#         score = 0.80
#         mean = 4.30
#         std = 1.283
# 3:-Random Forest Regressor
#         score = 0.85
#         mean = 3.75
#         std = 1.10
# 4:-Decision Tree Regressor
#         score = 0.889
#         mean = 4.97
#         std = 1.15
